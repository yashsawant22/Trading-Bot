# %%
## Installing Kite Connect
pip install --upgrade kiteconnect
# Out:
#   File "<ipython-input-7-eb5362c6ecd6>", line 2
#     pip install --upgrade kiteconnect
#               ^
# SyntaxError: invalid syntax

# %%
pip install -U pip setuptools
# Out:
# Requirement already satisfied: pip in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (23.3.1)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (41.4.0)
# Collecting setuptools
#   Downloading setuptools-68.0.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.1 MB/s eta 0:00:0000:0100:01
# Downloading setuptools-68.0.0-py3-none-any.whl (804 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 14.8 MB/s eta 0:00:0000:01
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 41.4.0
#     Uninstalling setuptools-41.4.0:
#       Successfully uninstalled setuptools-41.4.0
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 3.3.6 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 3.3.6 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# spacy 3.0.5 requires typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# swachhdata 1.2.2 requires pandas>=1.1.4, but you have pandas 1.0.3 which is incompatible.
# thinc 8.0.2 requires typing-extensions<4.0.0.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.7.1 which is incompatible.
# Successfully installed pip-24.0 setuptools-68.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
## Put this code on terminal to install
xcode-select --install
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52dd19dcfcca> in <module>
# ----> 1 xcode-select --install
#
# NameError: name 'xcode' is not defined

# %%
pip install --upgrade cryptography pyOpenSSL
# Out:
# Requirement already satisfied: cryptography in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (2.7)
# Collecting cryptography
#   Downloading cryptography-42.0.4-cp37-abi3-macosx_10_12_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: pyOpenSSL in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (19.0.0)
# Collecting pyOpenSSL
#   Downloading pyOpenSSL-24.0.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: cffi>=1.12 in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (from cryptography) (1.12.3)
# Requirement already satisfied: pycparser in /Users/yashsawant/opt/anaconda3/lib/python3.7/site-packages (from cffi>=1.12->cryptography) (2.19)
# Downloading cryptography-42.0.4-cp37-abi3-macosx_10_12_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.0 MB/s eta 0:00:0000:0100:01
# Downloading pyOpenSSL-24.0.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: cryptography, pyOpenSSL
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 2.7
#     Uninstalling cryptography-2.7:
#       Successfully uninstalled cryptography-2.7
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 19.0.0
#     Uninstalling pyOpenSSL-19.0.0:
#       Successfully uninstalled pyOpenSSL-19.0.0
# Successfully installed cryptography-42.0.4 pyOpenSSL-24.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
from kiteconnect import KiteConnect

# %%
logging.basicConfig(level=logging.DEBUG)

kite = KiteConnect(api_key="yiudvhy29jzifvqj")

# Redirect the user to the login url obtained
# from kite.login_url(), and receive the request_token
# from the registered redirect url after the login flow.
# Once you have the request_token, obtain the access_token
# as follows.

# %%
kite.login_url()
##OPEN link below to get request token
# Out:
# 'https://kite.zerodha.com/connect/login?api_key=yiudvhy29jzifvqj&v=3'

# %%
##http://127.0.0.1/?type=login&status=success&request_token=vY4qjldvneajXM8NClq9gpdiQ7ygzDeB&action=login

# %%
data = kite.generate_session("GyyhegGbt4WtT4Gil1KR7T4StRm7h4y2", api_secret="g2uy1opfnmnd728fu4x8wq9hax9jnf2s")

kite.set_access_token(data["access_token"])
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /session/token HTTP/1.1" 200 None

# %%
## GET previous orders
kite.orders()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /orders HTTP/1.1" 200 None
# [{'placed_by': 'WC1649',
#   'order_id': '240221400884878',
#   'exchange_order_id': '1708486200036667867',
#   'parent_order_id': None,
#   'status': 'COMPLETE',
#   'status_message': None,
#   'status_message_raw': None,
#   'order_timestamp': datetime.datetime(2024, 2, 21, 9, 58, 2),
#   'exchange_update_timestamp': '2024-02-21 09:58:02',
#   'exchange_timestamp': datetime.datetime(2024, 2, 21, 9, 58, 2),
#   'variety': 'regular',
#   'modified': False,
#   'exchange': 'BSE',
#   'tradingsymbol': 'IDFCFIRSTB',
#   'instrument_token': 138095876,
#   'order_type': 'MARKET',
#   'transaction_type': 'SELL',
#   'validity': 'DAY',
#   'validity_ttl': 0,
#   'product': 'CNC',
#   'quantity': 20,
#   'disclosed_quantity': 0,
#   'price': 0,
#   'trigger_price': 0,
#   'average_price': 81.95,
#   'filled_quantity': 20,
#   'pending_quantity': 0,
#   'cancelled_quantity': 0,
#   'market_protection': 0,
#   'meta': {},
#   'tag': None,
#   'guid': '01XCAO11BF1TpYn'}]

# %%
kite.instruments()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /instruments HTTP/1.1" 200 1279159
# [OrderedDict([('instrument_token', 258770438),
#               ('exchange_token', '1010822'),
#               ('tradingsymbol', 'EURINR24APRFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 262676230),
#               ('exchange_token', '1026079'),
#               ('tradingsymbol', 'EURINR24AUGFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 8, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268449030),
#               ('exchange_token', '1048629'),
#               ('tradingsymbol', 'EURINR24DECFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 12, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 256445190),
#               ('exchange_token', '1001739'),
#               ('tradingsymbol', 'EURINR24FEBFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 2, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 261799430),
#               ('exchange_token', '1022654'),
#               ('tradingsymbol', 'EURINR24JULFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 7, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 260801030),
#               ('exchange_token', '1018754'),
#               ('tradingsymbol', 'EURINR24JUNFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 6, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 257900806),
#               ('exchange_token', '1007425'),
#               ('tradingsymbol', 'EURINR24MARFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 259909382),
#               ('exchange_token', '1015271'),
#               ('tradingsymbol', 'EURINR24MAYFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 5, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 265969926),
#               ('exchange_token', '1038945'),
#               ('tradingsymbol', 'EURINR24NOVFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 264741126),
#               ('exchange_token', '1034145'),
#               ('tradingsymbol', 'EURINR24OCTFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 10, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 263556614),
#               ('exchange_token', '1029518'),
#               ('tradingsymbol', 'EURINR24SEPFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269248262),
#               ('exchange_token', '1051751'),
#               ('tradingsymbol', 'EURINR25JANFUT'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2025, 1, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 258770182),
#               ('exchange_token', '1010821'),
#               ('tradingsymbol', 'GBPINR24APRFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 262675974),
#               ('exchange_token', '1026078'),
#               ('tradingsymbol', 'GBPINR24AUGFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 8, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268448774),
#               ('exchange_token', '1048628'),
#               ('tradingsymbol', 'GBPINR24DECFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 12, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 256444934),
#               ('exchange_token', '1001738'),
#               ('tradingsymbol', 'GBPINR24FEBFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 2, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 261799174),
#               ('exchange_token', '1022653'),
#               ('tradingsymbol', 'GBPINR24JULFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 7, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 260800774),
#               ('exchange_token', '1018753'),
#               ('tradingsymbol', 'GBPINR24JUNFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 6, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 257900550),
#               ('exchange_token', '1007424'),
#               ('tradingsymbol', 'GBPINR24MARFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 259909126),
#               ('exchange_token', '1015270'),
#               ('tradingsymbol', 'GBPINR24MAYFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 5, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 265969670),
#               ('exchange_token', '1038944'),
#               ('tradingsymbol', 'GBPINR24NOVFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 264740870),
#               ('exchange_token', '1034144'),
#               ('tradingsymbol', 'GBPINR24OCTFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 10, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 263556358),
#               ('exchange_token', '1029517'),
#               ('tradingsymbol', 'GBPINR24SEPFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269248006),
#               ('exchange_token', '1051750'),
#               ('tradingsymbol', 'GBPINR25JANFUT'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2025, 1, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 258770694),
#               ('exchange_token', '1010823'),
#               ('tradingsymbol', 'JPYINR24APRFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 262676486),
#               ('exchange_token', '1026080'),
#               ('tradingsymbol', 'JPYINR24AUGFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 8, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268449286),
#               ('exchange_token', '1048630'),
#               ('tradingsymbol', 'JPYINR24DECFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 12, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 256445446),
#               ('exchange_token', '1001740'),
#               ('tradingsymbol', 'JPYINR24FEBFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 2, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 261799686),
#               ('exchange_token', '1022655'),
#               ('tradingsymbol', 'JPYINR24JULFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 7, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 260801286),
#               ('exchange_token', '1018755'),
#               ('tradingsymbol', 'JPYINR24JUNFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 6, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 257901062),
#               ('exchange_token', '1007426'),
#               ('tradingsymbol', 'JPYINR24MARFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 259909638),
#               ('exchange_token', '1015272'),
#               ('tradingsymbol', 'JPYINR24MAYFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 5, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 265970182),
#               ('exchange_token', '1038946'),
#               ('tradingsymbol', 'JPYINR24NOVFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 264741382),
#               ('exchange_token', '1034146'),
#               ('tradingsymbol', 'JPYINR24OCTFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 10, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 263556870),
#               ('exchange_token', '1029519'),
#               ('tradingsymbol', 'JPYINR24SEPFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269248518),
#               ('exchange_token', '1051752'),
#               ('tradingsymbol', 'JPYINR25JANFUT'),
#               ('name', 'JPYINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2025, 1, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 267271430),
#               ('exchange_token', '1044029'),
#               ('tradingsymbol', 'USDINR24223FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 2, 23)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268093190),
#               ('exchange_token', '1047239'),
#               ('tradingsymbol', 'USDINR24301FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 1)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268321286),
#               ('exchange_token', '1048130'),
#               ('tradingsymbol', 'USDINR24307FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 7)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268554246),
#               ('exchange_token', '1049040'),
#               ('tradingsymbol', 'USDINR24315FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 15)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268784390),
#               ('exchange_token', '1049939'),
#               ('tradingsymbol', 'USDINR24322FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 22)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268922118),
#               ('exchange_token', '1050477'),
#               ('tradingsymbol', 'USDINR24328FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269107206),
#               ('exchange_token', '1051200'),
#               ('tradingsymbol', 'USDINR24405FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 5)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550620422),
#               ('exchange_token', '2150861'),
#               ('tradingsymbol', 'USDINR24412FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 12)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269548294),
#               ('exchange_token', '1052923'),
#               ('tradingsymbol', 'USDINR24419FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 19)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 551310854),
#               ('exchange_token', '2153558'),
#               ('tradingsymbol', 'USDINR24503FUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 5, 3)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 258769926),
#               ('exchange_token', '1010820'),
#               ('tradingsymbol', 'USDINR24APRFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 262675718),
#               ('exchange_token', '1026077'),
#               ('tradingsymbol', 'USDINR24AUGFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 8, 28)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 268448518),
#               ('exchange_token', '1048627'),
#               ('tradingsymbol', 'USDINR24DECFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 12, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 256444678),
#               ('exchange_token', '1001737'),
#               ('tradingsymbol', 'USDINR24FEBFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 2, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 261798918),
#               ('exchange_token', '1022652'),
#               ('tradingsymbol', 'USDINR24JULFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 7, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 260800518),
#               ('exchange_token', '1018752'),
#               ('tradingsymbol', 'USDINR24JUNFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 6, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 257900294),
#               ('exchange_token', '1007423'),
#               ('tradingsymbol', 'USDINR24MARFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 3, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 259908870),
#               ('exchange_token', '1015269'),
#               ('tradingsymbol', 'USDINR24MAYFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 5, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 265969158),
#               ('exchange_token', '1038942'),
#               ('tradingsymbol', 'USDINR24NOVFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 11, 27)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 264740614),
#               ('exchange_token', '1034143'),
#               ('tradingsymbol', 'USDINR24OCTFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 10, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 263556102),
#               ('exchange_token', '1029516'),
#               ('tradingsymbol', 'USDINR24SEPFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 269247750),
#               ('exchange_token', '1051749'),
#               ('tradingsymbol', 'USDINR25JANFUT'),
#               ('name', 'USDINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2025, 1, 29)),
#               ('strike', 0.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'FUT'),
#               ('segment', 'BCD-FUT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550728710),
#               ('exchange_token', '2151284'),
#               ('tradingsymbol', 'EURINR24APR85.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550725126),
#               ('exchange_token', '2151270'),
#               ('tradingsymbol', 'EURINR24APR85.25PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550834950),
#               ('exchange_token', '2151699'),
#               ('tradingsymbol', 'EURINR24APR85.5CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550831110),
#               ('exchange_token', '2151684'),
#               ('tradingsymbol', 'EURINR24APR85.5PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550717958),
#               ('exchange_token', '2151242'),
#               ('tradingsymbol', 'EURINR24APR85.75CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550714374),
#               ('exchange_token', '2151228'),
#               ('tradingsymbol', 'EURINR24APR85.75PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550811398),
#               ('exchange_token', '2151607'),
#               ('tradingsymbol', 'EURINR24APR85CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550805254),
#               ('exchange_token', '2151583'),
#               ('tradingsymbol', 'EURINR24APR85PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 85.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550863366),
#               ('exchange_token', '2151810'),
#               ('tradingsymbol', 'EURINR24APR86.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550860038),
#               ('exchange_token', '2151797'),
#               ('tradingsymbol', 'EURINR24APR86.25PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550974726),
#               ('exchange_token', '2152245'),
#               ('tradingsymbol', 'EURINR24APR86.5CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550970630),
#               ('exchange_token', '2152229'),
#               ('tradingsymbol', 'EURINR24APR86.5PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550850566),
#               ('exchange_token', '2151760'),
#               ('tradingsymbol', 'EURINR24APR86.75CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550847238),
#               ('exchange_token', '2151747'),
#               ('tradingsymbol', 'EURINR24APR86.75PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550703110),
#               ('exchange_token', '2151184'),
#               ('tradingsymbol', 'EURINR24APR86CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550983174),
#               ('exchange_token', '2152278'),
#               ('tradingsymbol', 'EURINR24APR86PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 86.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550718470),
#               ('exchange_token', '2151244'),
#               ('tradingsymbol', 'EURINR24APR87.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550714630),
#               ('exchange_token', '2151229'),
#               ('tradingsymbol', 'EURINR24APR87.25PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550821638),
#               ('exchange_token', '2151647'),
#               ('tradingsymbol', 'EURINR24APR87.5CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550815494),
#               ('exchange_token', '2151623'),
#               ('tradingsymbol', 'EURINR24APR87.5PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550706950),
#               ('exchange_token', '2151199'),
#               ('tradingsymbol', 'EURINR24APR87.75CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550702086),
#               ('exchange_token', '2151180'),
#               ('tradingsymbol', 'EURINR24APR87.75PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550835974),
#               ('exchange_token', '2151703'),
#               ('tradingsymbol', 'EURINR24APR87CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550831878),
#               ('exchange_token', '2151687'),
#               ('tradingsymbol', 'EURINR24APR87PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 87.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550851846),
#               ('exchange_token', '2151765'),
#               ('tradingsymbol', 'EURINR24APR88.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550848006),
#               ('exchange_token', '2151750'),
#               ('tradingsymbol', 'EURINR24APR88.25PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550964486),
#               ('exchange_token', '2152205'),
#               ('tradingsymbol', 'EURINR24APR88.5CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550960390),
#               ('exchange_token', '2152189'),
#               ('tradingsymbol', 'EURINR24APR88.5PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550871046),
#               ('exchange_token', '2151840'),
#               ('tradingsymbol', 'EURINR24APR88.75CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550867718),
#               ('exchange_token', '2151827'),
#               ('tradingsymbol', 'EURINR24APR88.75PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550975238),
#               ('exchange_token', '2152247'),
#               ('tradingsymbol', 'EURINR24APR88CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550971142),
#               ('exchange_token', '2152231'),
#               ('tradingsymbol', 'EURINR24APR88PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 88.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550707462),
#               ('exchange_token', '2151201'),
#               ('tradingsymbol', 'EURINR24APR89.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550702854),
#               ('exchange_token', '2151183'),
#               ('tradingsymbol', 'EURINR24APR89.25PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550808070),
#               ('exchange_token', '2151594'),
#               ('tradingsymbol', 'EURINR24APR89.5CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550803974),
#               ('exchange_token', '2151578'),
#               ('tradingsymbol', 'EURINR24APR89.5PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550726918),
#               ('exchange_token', '2151277'),
#               ('tradingsymbol', 'EURINR24APR89.75CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550723334),
#               ('exchange_token', '2151263'),
#               ('tradingsymbol', 'EURINR24APR89.75PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550821894),
#               ('exchange_token', '2151648'),
#               ('tradingsymbol', 'EURINR24APR89CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550816006),
#               ('exchange_token', '2151625'),
#               ('tradingsymbol', 'EURINR24APR89PE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 89.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 550934534),
#               ('exchange_token', '2152088'),
#               ('tradingsymbol', 'EURINR24APR90.25CE'),
#               ('name', 'EURINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 4, 26)),
#               ('strike', 90.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
# ...
#               ('tradingsymbol', 'GBPINR24SEP104PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 104.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546420742),
#               ('exchange_token', '2134456'),
#               ('tradingsymbol', 'GBPINR24SEP105.25CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546417414),
#               ('exchange_token', '2134443'),
#               ('tradingsymbol', 'GBPINR24SEP105.25PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546467846),
#               ('exchange_token', '2134640'),
#               ('tradingsymbol', 'GBPINR24SEP105.5CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546465286),
#               ('exchange_token', '2134630'),
#               ('tradingsymbol', 'GBPINR24SEP105.5PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546411526),
#               ('exchange_token', '2134420'),
#               ('tradingsymbol', 'GBPINR24SEP105.75CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546406406),
#               ('exchange_token', '2134400'),
#               ('tradingsymbol', 'GBPINR24SEP105.75PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546476038),
#               ('exchange_token', '2134672'),
#               ('tradingsymbol', 'GBPINR24SEP105CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546473734),
#               ('exchange_token', '2134663'),
#               ('tradingsymbol', 'GBPINR24SEP105PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 105.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546512390),
#               ('exchange_token', '2134814'),
#               ('tradingsymbol', 'GBPINR24SEP106.25CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546508038),
#               ('exchange_token', '2134797'),
#               ('tradingsymbol', 'GBPINR24SEP106.25PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546566150),
#               ('exchange_token', '2135024'),
#               ('tradingsymbol', 'GBPINR24SEP106.5CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546562054),
#               ('exchange_token', '2135008'),
#               ('tradingsymbol', 'GBPINR24SEP106.5PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546501894),
#               ('exchange_token', '2134773'),
#               ('tradingsymbol', 'GBPINR24SEP106.75CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546497030),
#               ('exchange_token', '2134754'),
#               ('tradingsymbol', 'GBPINR24SEP106.75PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546573830),
#               ('exchange_token', '2135054'),
#               ('tradingsymbol', 'GBPINR24SEP106CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546571526),
#               ('exchange_token', '2135045'),
#               ('tradingsymbol', 'GBPINR24SEP106PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 106.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546412038),
#               ('exchange_token', '2134422'),
#               ('tradingsymbol', 'GBPINR24SEP107.25CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546406918),
#               ('exchange_token', '2134402'),
#               ('tradingsymbol', 'GBPINR24SEP107.25PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546460934),
#               ('exchange_token', '2134613'),
#               ('tradingsymbol', 'GBPINR24SEP107.5CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546456326),
#               ('exchange_token', '2134595'),
#               ('tradingsymbol', 'GBPINR24SEP107.5PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546401030),
#               ('exchange_token', '2134379'),
#               ('tradingsymbol', 'GBPINR24SEP107.75CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546397190),
#               ('exchange_token', '2134364'),
#               ('tradingsymbol', 'GBPINR24SEP107.75PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546468614),
#               ('exchange_token', '2134643'),
#               ('tradingsymbol', 'GBPINR24SEP107CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 546466054),
#               ('exchange_token', '2134633'),
#               ('tradingsymbol', 'GBPINR24SEP107PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 107.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547081734),
#               ('exchange_token', '2137038'),
#               ('tradingsymbol', 'GBPINR24SEP108.25CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547081478),
#               ('exchange_token', '2137037'),
#               ('tradingsymbol', 'GBPINR24SEP108.25PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.25),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547187462),
#               ('exchange_token', '2137451'),
#               ('tradingsymbol', 'GBPINR24SEP108.5CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547184902),
#               ('exchange_token', '2137441'),
#               ('tradingsymbol', 'GBPINR24SEP108.5PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.5),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547822854),
#               ('exchange_token', '2139933'),
#               ('tradingsymbol', 'GBPINR24SEP108.75CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547822086),
#               ('exchange_token', '2139930'),
#               ('tradingsymbol', 'GBPINR24SEP108.75PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.75),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547078150),
#               ('exchange_token', '2137024'),
#               ('tradingsymbol', 'GBPINR24SEP108CE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'CE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  OrderedDict([('instrument_token', 547077894),
#               ('exchange_token', '2137023'),
#               ('tradingsymbol', 'GBPINR24SEP108PE'),
#               ('name', 'GBPINR'),
#               ('last_price', 0.0),
#               ('expiry', datetime.date(2024, 9, 26)),
#               ('strike', 108.0),
#               ('tick_size', 0.0025),
#               ('lot_size', 1),
#               ('instrument_type', 'PE'),
#               ('segment', 'BCD-OPT'),
#               ('exchange', 'BCD')]),
#  ...]

# %%
# Place an order
try:
    order_id = kite.place_order(tradingsymbol="INFY",
                                exchange=kite.EXCHANGE_NSE,
                                transaction_type=kite.TRANSACTION_TYPE_BUY,
                                quantity=1,
                                variety=kite.VARIETY_AMO,
                                order_type=kite.ORDER_TYPE_MARKET,
                                product=kite.PRODUCT_CNC,
                                validity=kite.VALIDITY_DAY)

    logging.info("Order placed. ID is: {}".format(order_id))
except Exception as e:
    logging.info("Order placement failed: {}".format(e.message))

# Fetch all orders
kite.orders()

# Get instruments
kite.instruments()

# Place an mutual fund order
kite.place_mf_order(
    tradingsymbol="INF090I01239",
    transaction_type=kite.TRANSACTION_TYPE_BUY,
    amount=5000,
    tag="mytag"
)

# Cancel a mutual fund order
kite.cancel_mf_order(order_id="order_id")

# Get mutual fund instruments
kite.mf_instruments()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/amo HTTP/1.1" 400 217
# ---------------------------------------------------------------------------
# InputException                            Traceback (most recent call last)
# <ipython-input-15-194a29807bd4> in <module>
#       9                                 product=kite.PRODUCT_CNC,
# ---> 10                                 validity=kite.VALIDITY_DAY)
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kiteconnect/connect.py in place_order(self, variety, exchange, tradingsymbol, transaction_type, quantity, product, order_type, price, validity, validity_ttl, disclosed_quantity, trigger_price, iceberg_legs, iceberg_quantity, auction_number, tag)
#     362                           url_args={"variety": variety},
# --> 363                           params=params)["order_id"]
#     364
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kiteconnect/connect.py in _post(self, route, url_args, params, is_json, query_params)
#     864         """Alias for sending a POST request."""
# --> 865         return self._request(route, "POST", url_args=url_args, params=params, is_json=is_json, query_params=query_params)
#     866
#
# ~/opt/anaconda3/lib/python3.7/site-packages/kiteconnect/connect.py in _request(self, route, method, url_args, params, is_json, query_params)
#     936                 exp = getattr(ex, data.get("error_type"), ex.GeneralException)
# --> 937                 raise exp(data["message"], code=r.status_code)
#     938
#
# InputException: AMOs can only be placed after trading hours. Try placing a regular order or use [GTT](https://zrd.sh/gtt-support) to place long-standing orders.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-194a29807bd4> in <module>
#      12     logging.info("Order placed. ID is: {}".format(order_id))
#      13 except Exception as e:
# ---> 14     logging.info("Order placement failed: {}".format(e.message))
#      15
#      16 # Fetch all orders
#
# AttributeError: 'InputException' object has no attribute 'message'

# %%
#git pass- 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

# !cd /Users/yashsawant/Trading-Bot
# !git push https://github.com/yashsawant22/Trading-Bot.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
positions = kite.positions()
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/positions HTTP/1.1" 200 None

# %%
##positions['net'][0]['tradingsymbol']=='IDFCFIRSTB'
# Out:
# True

# %%
##Placing an order
kite.place_order(tradingsymbol="BIOCON",
                                exchange=kite.EXCHANGE_NSE,
                                transaction_type=kite.TRANSACTION_TYPE_SELL,
                                quantity=10,
                                variety=kite.VARIETY_REGULAR,
                                order_type=kite.ORDER_TYPE_MARKET,
                                product=kite.PRODUCT_CNC,
                                validity=kite.VALIDITY_DAY)
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "POST /orders/regular HTTP/1.1" 200 None
# '240221402027650'

# %%
import pandas as pd

# %%
positions_df= pd.DataFrame(positions['net'])

# %%
positions_df[positions_df['tradingsymbol']=='BIOCON']
# Out:
#   tradingsymbol exchange  instrument_token product  quantity  \
# 1        BIOCON      NSE           2911489     CNC       -10
#
#    overnight_quantity  multiplier  average_price  close_price  last_price  \
# 1                   0           1          277.6            0       277.6
#
#    ...  sell_quantity  sell_price  sell_value  sell_m2m  day_buy_quantity  \
# 1  ...             10       277.6        2776      2776                 0
#
#    day_buy_price  day_buy_value  day_sell_quantity  day_sell_price  \
# 1              0              0                 10           277.6
#
#    day_sell_value
# 1            2776
#
# [1 rows x 29 columns]

# %%
holdings = pd.DataFrame(kite.holdings())
# Out:
# DEBUG:urllib3.connectionpool:https://api.kite.trade:443 "GET /portfolio/holdings HTTP/1.1" 200 None

# %%
holdings
# Out:
#    tradingsymbol exchange  instrument_token          isin product  price  \
# 0         BIOCON      BSE         136325892  INE376G01013     CNC      0
# 1            HPL      NSE           4781825  INE495S01016     CNC      0
# 2          HUDCO      BSE         138375684  INE031A01017     CNC      0
# 3     IDFCFIRSTB      BSE         138095876  INE092T01019     CNC      0
# 4            ITC      NSE            424961  INE154A01025     CNC      0
# 5        OLECTRA      BSE         136304388  INE260D01016     CNC      0
# 6      POWERGRID      BSE         136421892  INE752E01010     CNC      0
# 7           SBIN      BSE         128028676  INE062A01020     CNC      0
# 8           SJVN      NSE           4834049  INE002L01015     CNC      0
# 9       SPICEJET      BSE         128072964  INE285B01017     CNC      0
# 10     SUZLON-BE      NSE           3077377  INE040H01021     CNC      0
# 11    TATAMOTORS      BSE         128145924  INE155A01022     CNC      0
# 12      TVSMOTOR      BSE         136279812  INE494B01023     CNC      0
#
#     quantity  used_quantity  t1_quantity  realised_quantity  ...  \
# 0         30             10            0                 30  ...
# 1         16              0            0                 16  ...
# 2         18              0            0                 18  ...
# 3        104             20            0                104  ...
# 4         30              0            0                 30  ...
# 5          2              0            0                  2  ...
# 6         23              0            0                 23  ...
# 7         10              0            0                 10  ...
# 8         40              0            0                 40  ...
# 9         75              0            0                 75  ...
# 10        70              0            0                 70  ...
# 11        22              0            0                 22  ...
# 12         5              0            0                  5  ...
#
#     short_quantity collateral_quantity collateral_type  discrepancy  \
# 0                0                   0                        False
# 1                0                   0                        False
# 2                0                   0                        False
# 3                0                   0                        False
# 4                0                   0                        False
# 5                0                   0                        False
# 6                0                   0                        False
# 7                0                   0                        False
# 8                0                   0                        False
# 9                0                   0                        False
# 10               0                   0                        False
# 11               0                   0                        False
# 12               0                   0                        False
#
#     average_price  last_price close_price           pnl  day_change  \
# 0      258.000000      277.70      281.50    591.000000       -3.80
# 1      300.050000      363.95      372.95   1022.400000       -9.00
# 2      204.000000      202.95      198.70    -18.900000        4.25
# 3       48.331451       81.15       81.75   3413.129096       -0.60
# 4      326.666666      407.60      406.10   2428.000020        1.50
# 5     2012.000000     2091.70     2090.00    159.400000        1.70
# 6      268.584782      283.15      287.95    335.000014       -4.80
# 7      395.470000      772.60      760.10   3771.300000       12.50
# 8      126.500000      120.45      123.15   -242.000000       -2.70
# 9       70.060000       67.55       68.18   -188.250000       -0.63
# 10      46.645000       45.90       45.80    -52.150000        0.10
# 11     458.927272      928.85      926.40  10338.300016        2.45
# 12    2026.970000     2114.95     2119.35    439.900000       -4.40
#
#     day_change_percentage
# 0               -1.349911
# 1               -2.413192
# 2                2.138903
# 3               -0.733945
# 4                0.369367
# 5                0.081340
# 6               -1.666956
# 7                1.644520
# 8               -2.192448
# 9               -0.924025
# 10               0.218341
# 11               0.264465
# 12              -0.207611
#
# [13 rows x 24 columns]
